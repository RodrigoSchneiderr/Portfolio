# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoSchneiderr/Portfolio/blob/main/Redes_Neurais_Estrutura_B%C3%A1sica_em_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np


tns1 = torch.randn (7,7,3)
tns2 = torch.randn (147, 1)


tns1 = tns1.view(-1, 1)
soma = tns1 + tns2

print(soma)
# Out:
# tensor([[-4.2727e-01],
#         [ 1.2251e-01],
#         [-4.3344e-01],
#         [ 1.4246e+00],
#         [-6.7503e-01],
#         [-1.2164e+00],
#         [-1.9416e+00],
#         [ 1.7415e+00],
#         [ 1.9516e+00],
#         [ 1.4498e+00],
#         [-6.3365e-01],
#         [ 1.9426e-01],
#         [-9.4805e-01],
#         [-2.0471e+00],
#         [ 3.4635e-01],
#         [ 1.5694e+00],
#         [-1.8219e+00],
#         [ 8.9842e-01],
#         [ 5.6853e-01],
#         [ 5.5430e-01],
#         [-1.4109e-01],
#         [-2.3063e+00],
#         [-1.3522e+00],
#         [-2.8453e-01],
#         [-2.8481e-01],
#         [-7.8168e-01],
#         [-8.7093e-01],
#         [ 1.1088e+00],
#         [ 1.6791e+00],
#         [-1.6234e+00],
#         [ 9.8557e-02],
#         [-4.5829e-01],
#         [ 8.3504e-01],
#         [-1.5803e-01],
#         [ 1.6249e+00],
#         [-2.6391e+00],
#         [ 1.4653e+00],
#         [-1.4174e-02],
#         [-1.4889e-01],
#         [ 1.0669e+00],
# ...

# %%
from sklearn.datasets import make_classification, make_blobs

np.random.seed(30)
X, Y = make_classification(n_features=2, n_redundant=0, n_informative=1, n_clusters_per_class=1)

plt.scatter(X[:, 0], X[:, 1], marker='o', c=Y, edgecolor='k')

p= X[10]
print(Y[10])
plt.plot(p[0], p[1], marker='^',markersize=10)
# Out:
# 1

# %%
def plotmodel (w1, w2, b):

  plt.scatter(X[:, 0], X[:, 1], marker='o', c=Y, edgecolor='k')

  xmin, xmax = plt.gca().get_xlim()
  ymin, ymax = plt.gca().get_ylim()

  x = np.linspace(-2, 4, 50)
  y = (-w1*x -b)/w2

  plt.axvline (0, -1, 1, color='k', linewidth=1)
  plt.axhline (0, -2, 4, color='k', linewidth=1)
  plt.plot(x, y)
  plt.grid(True)

  plt.xlim(xmin, xmax)
  plt.ylim(ymin, ymax)


w1= 0.2
w2 = 7
b = -0.1
plotmodel(w1, w2, b)

p = (0.5, -1)
print(w1 * p[0] + w2 * p[1] + b)
# Out:
# -7.0

# %%
def classify(ponto, w1, w2, b):
  ret = w1 * ponto[0] + w2 * ponto[1] + b

  if ret > 0:
    return 1, 'yellow'
  else:
     return 0, 'blue'

p = (2, -1)
classe, cor = classify(p, w1, w2, b)
print (classe, cor)

plotmodel(w1, w2, b)
plt.plot(p[0], p[1], marker='^', color=cor, markersize=30)
# Out:
# 0 blue

# %%
acertos = 0

for k in range(len(X)):
  categ, _ = classify(X[k], w1, w2, b)
  if categ == Y[k]:
    acertos += 1

print("Acurácia: {0}".format(100*acertos/len(X)))
# Out:
# Acurácia: 91.0

# %%
import torch
from torch import nn #neural networks

perceptron = nn.Linear(in_features=3, out_features=1)

# %%
for nome, tensor in perceptron.named_parameters():
  print(nome, tensor.data)
# Out:
# weight tensor([[-0.3854, -0.0706,  0.1834]])
# bias tensor([-0.2552])

# %%
import torch
import matplotlib.pyplot as plt
from torch import nn #neural networks


from sklearn.datasets import make_classification, make_blobs

np.random.seed(46)
X, Y = make_classification(n_features=2, n_redundant=0, n_informative=1, n_clusters_per_class=1)

def plotmodel (w1, w2, b):

  plt.scatter(X[:, 0], X[:, 1], marker='o', c=Y, edgecolor='k')

  xmin, xmax = plt.gca().get_xlim()
  ymin, ymax = plt.gca().get_ylim()

  x = np.linspace(-2, 4, 50)
  y = (-w1*x -b)/w2

  plt.axvline (0, -1, 1, color='k', linewidth=1)
  plt.axhline (0, -2, 4, color='k', linewidth=1)
  plt.plot(x, y)
  plt.grid(True)

  plt.xlim(xmin, xmax)
  plt.ylim(ymin, ymax)


w1= 5
w2 = 1
b = -0.4
plotmodel(w1, w2, b)

p = (0.5, -1)
print(w1 * p[0] + w2 * p[1] + b)
# Out:
# 1.1

# %%
perceptron = nn.Linear(2, 1)
sigmoide = nn.Sigmoid()

perceptron.weight = nn.Parameter(torch.Tensor([[5, 1]]))
perceptron.bias = nn.Parameter(torch.Tensor([0.4]))

print(perceptron.weight.data)
print(perceptron.bias.data)

w1= 5
w2 = 1
b = -0.4
# Out:
# tensor([[5., 1.]])
# tensor([0.4000])

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import torch
import numpy as np
from torch import nn # reural networks

X1, Y1 = make_moons(n_samples=300, noise=0.2)
plt.scatter(X1[:,0], X1[:,1], marker='o',c=Y1, s=25, edgecolor='k')

input_size = 2
hidden_size = 8
output_size = 1

net = nn.Sequential(nn.Linear(in_features=input_size, out_features=hidden_size),    #hidden (camada escondida)
                    nn.ReLU(),      #ativação não linear
                    nn.Linear(in_features=hidden_size, out_features=output_size))    #output (saída)

print(net)
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=8, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
from torchsummary import summary
summary(net, input_size=(1, input_size))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-def45b72f3d7> in <cell line: 2>()
#       1 from torchsummary import summary
# ----> 2 summary(net, input_size=(1, input_size))
#
# /usr/local/lib/python3.10/dist-packages/torchsummary/torchsummary.py in summary(model, input_size, batch_size, device)
#      70     # make a forward pass
#      71     # print(x.shape)
# ---> 72     model(*x)
#      73
#      74     # remove these hooks
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# ...

# %%
print(X1.shape)
tensor = torch.from_numpy(X1).float()
pred = net(tensor)
print(pred.size)
# Out:
# (300, 2)
# <built-in method size of Tensor object at 0x7d18d618b290>

# %%
class MinhaRede(nn.Module):
  def __init__(self, input_size, hidden_size, output_size):
    super(MinhaRede, self).__init__()

    # Definir Arquitetura
    self.hidden = nn.Linear(input_size, hidden_size)
    self.relu = nn.ReLU()
    self.output = nn.Linear(hidden_size, output_size)

  def forward(self, X):

  #Gerar uma saída a partir do X
    hidden = self.relu(self.hidden(X))
    output = self.output(hidden)

    return output

# %%
#Instanciando a rede

input_size = 2
hidden_size = 8
output_size = 1

net = MinhaRede(input_size, hidden_size, output_size) # O método __init__()
print(net)
# Out:
# MinhaRede(
#   (hidden): Linear(in_features=2, out_features=8, bias=True)
#   (relu): ReLU()
#   (output): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
print(X1.shape)
tensor = torch.from_numpy(X1).float()
pred = net(tensor)
print(pred.size())
# Out:
# (300, 2)
# torch.Size([300, 1])

# %%
if torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')

print(device)
# Out:
# cuda

# %%
input_size = 2
hidden_size = 8
output_size = 1

net = MinhaRede(input_size, hidden_size, output_size) # O método __init__()
net = net.to(device)
print(net)
# Out:
# MinhaRede(
#   (hidden): Linear(in_features=2, out_features=8, bias=True)
#   (relu): ReLU()
#   (output): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
print(X1.shape)
tensor = torch.from_numpy(X1).float()
tensor = tensor.to(device)
pred = net(tensor)
print(pred.size())
# Out:
# (300, 2)
# torch.Size([300, 1])

# %%
# Resumo do Código com módulo nn.Sequential

net_sequential = nn.Sequential(nn.Linear(in_features=3, out_features=6),
    nn.ReLU(),
    nn.Linear(in_features=6, out_features=3))

# %%
# Resumo do código com o nn.Module

class Net(nn.Module):

  def __init__(self, input_size, hidden_size, output_size):
    super(Net, self).__init__()

    #Difinir a arquitetura
    self.hidden = nn.Linear(input_size, hidden_size)
    self.relu = nn.ReLU()
    self.output = nn.Linear(hidden_size, output_size)

  def forward(self, X):

    #Gerar uma saída a partir do X
    hidden = self.relu(self.hidden(X))
    output = self.output(hidden)

    return output

net_mudule = Net(input_size=3, hidden_size=6, output_size=3)
